# %%
from importlib import reload
from app import audio
reload(audio)
from app.audio import process_audio_file, chunk_transcription_by_sentences

transcript = process_audio_file("recording1", "m4a")
print(transcript)
chunks = chunk_transcription_by_sentences(transcript, sentences_per_chunk=10, overlap_sentences=2)

for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}: {chunk}")
# Out:
# Hi, who are you?
#
# Hi, I'm participant 25362.
#
# Okay, hello. How are you today?
#
# I'm good, I'm nervous to be here.
#
# Nervous? Why are you nervous?
#
# Because I have so many issues and I don't know if you can help me, maybe.
#
# Okay, I see. Well, should we start with some questions and then we can figure out what is going on with you?
#
# Yeah, sounds good.
#
# How do you feel in general?
#
# I'm good in general. Like I mean I like where I live, I like my school, but it's very stressful living with the social services. All I'm thinking about is where am I going to live in three months, who's going to help me with stuff. So I'm stressed and have anxiety, I would say.
#
# Okay. Do you get any help with your stress from the social service?
#
# No, they only say that you have a lot of time, everything will work out.
#
# I see. Do you have any contact with any psychologist or doctors?
#
# No, I don't trust them.
#
# You don't trust them?
#
# No.
#
# Why don't you trust them?
#
# ...

# %%
from importlib import reload
from app import audio
reload(audio)
from app.audio import process_audio_file, chunk_transcription_by_sentences
chunks = chunk_transcription_by_sentences(transcript, sentences_per_chunk=10, overlap_sentences=2)

for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}: {chunk}")
# Out:
# Chunk 1: Hi! Who are you? Hi, I'm participant 25362. Okay, hello. How are you today? I'm good. I'm nervous to be here. Nervous? Why are you nervous? Because I have so many issues and I don't know if you can help me, maybe.
# Chunk 2:  Why are you nervous? Because I have so many issues and I don't know if you can help me, maybe. Okay, I see. Well, should we start with some questions and then we can figure out what is going on with you? Yes, sounds good. How do you feel in general? I'm good in general. I like where I live, I like my school, but it's very stressful living with the social services. All I'm thinking about is where am I going to live in three months, who's going to help me with stuff. So I'm stressed and have anxiety, I would say.
# ...

# %%
from importlib import reload
from app import main_workflow
reload(main_workflow)
from app.main_workflow import process_recording, prepare_survey

survey_questions, df = prepare_survey("survey_2")
process_recording("recording1", df, survey_questions, "m4a")
# Out:
# Successfully prepared survey from survey_2.xlsx
# 🎬 Starting processing for recording1.m4a
# 2025-07-15 14:32:44.873 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-15 14:32:44.874 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 🎵 Audio transcription completed in 10.02s
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\LocalFiles\surveytool\.venv\Lib\site-packages\streamlit\runtime\state\session_state.py:463, in SessionState.__getitem__(self, key)
#     462 try:
# --> 463     return self._getitem(widget_id, key)
#     464 except KeyError:
#
# ...
